# %% [markdown]
# # Actividad 2_7: Funciones, ficheros y excepciones.
#
# Descarga el archivo llamado nba.csv e introdúcelo en la misma carpeta en la que vas a solucionar este ejercicio.
#
# Este fichero CSV contiene información sobre los 30 equipos de la NBA en la temporada actual. La explicación de las columnas que contiene es la siguiente:
#
# - G -> Partidos jugados.
# - MP -> Minutos jugados.
# - FG -> Tidos de campo anotados.
# - FGA -> Tidos de campo intentados.
# - FG% -> Porcentaje de tiros de campo.
# - 3P -> Tiros de 3 puntos anotados.
# - 3PA -> Tiros de 3 puntos intentados.
# - 3P% -> Porcentaje de tiros de 3 puntos.
# - 2P ->  Tiros de 2 puntos anotados.
# - 2PA -> Tiros de 2 puntos intentados.
# - 2P% -> Porcentaje de tiros de 2 puntos.
# - FT -> Tiros libres anotados.
# - FTA -> Tiros libres intentados.
# - FT% -> Porcentaje de tiros libres.
# - ORB -> Rebotes ofensivos.
# - DRB -> Rebotes defensivos.
# - TRB -> Rebotes totales.
# - AST -> Asisencias (pases que acaban directamente en canasta).
# - STL -> Robos de balon.
# - BLK -> Tapones.
# - TOV -> Pérdidas.
# - PF -> Faltas personales.
# - PTS -> Puntos.

# %% [markdown]
# Debes escribir un programa que consiga los siguientes objetivos (introduce cuando sea necesario el tratamiento correspondiente de excepciones):
#
# 1. Debe importar los datos en un DataFrame.
# 2. Debe mostrar el menú que se muestra a continuación. Debes hacer cada una de las acciones del menú en una función separada. Para la función principal puedes usar un main o no, como lo consideres oportuno.
#
#     1 Añade Estado. (Esta función debe añadir una columna nueva con el Estado al que pertenece cada uno de los equipos de la NBA.)
#
#     2 Elimina columna. (Esta función debe pedir el nombre de una columna, comprobar que está bien y eliminar dicha columna).
#
#     3 Vuelve a cargar datos. (Esta función debe sobreescribir el DataFrame con los datos originales).
#
#     4 Ordena por columna. (Esta función debe pedir el nombre de una columna, comprobar que está bien y devovler los datos ordenados según dicha columna).
#
# 3. Crea una función que prediga en base a los datos que tienes y a las reglas que consideres oportuno el porcentaje de probabilidad de ganar la NBA en la temporada actual que tienen cada uno de estos 30 equipos. Para hacer esto deberás investigar cada uno de los datos y decidir el impacto que tienen en el juego.

# %%
# Código
import pandas as pd
df_nba = pd.read_csv("nba.csv")

def anade_estados(df):
    estados = ["Utah","North Carolina","Arizona","New York","Wisconsin","Tennessee","California","Georgia","Minnesota","California","Texas","Illinois","California","Florida","Oregon","Texas","Indiana","Colorado","Washington DC","Massachussets","Pennsylvania","Ohio","Toronto","Louisianna","California","Texas","New York","Florida","Michigan","Oklahoma"]
    df["Estados"] = estados
    return df
    
def carga_datos():
    df = pd.read_csv("nba.csv")
    return df

def elimina_columna(df):
    col1 = input("Di el nombre de la columna")
    df = df.drop(columns=[col1])
    return df
        
def ordena_columna(df):
    col2 = input("Di el nombre de la columna")
    df = df.sort_values(by=[col2], ascending= False)
    return df
        
def predecir(df):
    elegido = df.sort_values(by=["FG%", "TRB"], ascending=[False, False]).iloc[1]
    print(elegido)
    return df



while True:
    print("""Introduce una opción de las siguientes:
    1. Añade columna Estado.
    2. Elimina columna.
    3. Vuelve a cargar datos.
    4. Ordena por columna.
    5. Pinta dataframe.
    6. Predecir quien gana
    7. Salir.""")
    opcion = input("Opción: ")
    if opcion == "1":
        df_nba = anade_estados(df_nba)
    if opcion == "2":
        df_nba = elimina_columna(df_nba)        
    if opcion == "3":
        df_nba = carga_datos()
    if opcion == "4":
        df_nba = ordena_columna(df_nba)
    if opcion == "5":
        print(df_nba.head())
    if opcion == "6":
        df_nba = predecir(df_nba)
    if opcion == "7":
        break
print("Cerrando programa...")
# Out:
# Introduce una opción de las siguientes:
#     1. Añade columna Estado.
#     2. Elimina columna.
#     3. Vuelve a cargar datos.
#     4. Ordena por columna.
#     5. Pinta dataframe.
#     6. Predecir quien gana
#     7. Salir.
#    Rk               Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0   1          Utah Jazz  47  240.0  40.7  86.3  0.472  14.7  40.6  0.362
# 1   2  Charlotte Hornets  47  242.1  42.5  92.3  0.461  14.0  38.2  0.367
# 2   3       Phoenix Suns  45  240.6  42.5  89.4  0.476  11.5  31.7  0.363
# 3   4      Brooklyn Nets  46  241.1  41.8  88.2  0.474  11.1  31.7  0.352
# 4   5    Milwaukee Bucks  49  241.0  40.4  89.2  0.454  14.3  39.5  0.362
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.780  10.3  36.3  46.6  22.2  6.9  4.9  14.1  18.9  114.2
# 1  ...  0.736  10.6  33.9  44.4  27.1  8.8  5.1  13.1  19.3  114.1
# 2  ...  0.805  10.0  36.0  46.0  26.4  8.8  4.2  13.5  19.5  112.5
# 3  ...  0.827   9.8  35.5  45.3  25.6  7.0  5.5  14.2  20.1  112.2
# 4  ...  0.778  10.4  36.8  47.2  23.0  7.7  4.4  13.8  17.9  112.0
#
# [5 rows x 25 columns]
# Introduce una opción de las siguientes:
#     1. Añade columna Estado.
#     2. Elimina columna.
#     3. Vuelve a cargar datos.
#     4. Ordena por columna.
#     5. Pinta dataframe.
#     6. Predecir quien gana
#     7. Salir.
# Cerrando programa...

# %%
# Buscando correlacciones entre distintos campos
df_nba.corr(numeric_only=True).abs().sort_values(by= ["FG%"], ascending=False)
# Out:
#            Rk         G        MP        FG       FGA       FG%        3P  \
# FG%  0.700642  0.016866  0.075831  0.768017  0.119128  1.000000  0.037364
# 2P%  0.518201  0.096421  0.113470  0.487396  0.272913  0.793572  0.246156
# PTS  0.971318  0.098181  0.140234  0.878056  0.348405  0.776974  0.336149
# FG   0.847360  0.030144  0.201792  1.000000  0.543523  0.768017  0.030884
# Rk   1.000000  0.129002  0.093499  0.847360  0.401653  0.700642  0.344450
# 3P%  0.600578  0.060339  0.171472  0.468075  0.087542  0.619791  0.443144
# AST  0.492803  0.055617  0.136454  0.690943  0.265895  0.608967  0.013018
# 2P   0.474469  0.077412  0.220674  0.813984  0.480620  0.588684  0.605198
# DRB  0.350577  0.431705  0.026220  0.254680  0.125966  0.406894  0.130995
# ORB  0.121576  0.009501  0.019097  0.145494  0.655510  0.331860  0.079950
# 3PA  0.048610  0.212931  0.042684  0.297225  0.034507  0.309286  0.868544
# PF   0.010658  0.222024  0.252192  0.160968  0.072786  0.248948  0.194850
# FT%  0.011357  0.234713  0.073696  0.075099  0.395334  0.209860  0.189429
# FT   0.212320  0.036830  0.007275  0.116944  0.409139  0.171691  0.064657
# 2PA  0.203672  0.131106  0.154904  0.557989  0.626534  0.170133  0.724915
# FGA  0.401653  0.065681  0.203968  0.543523  1.000000  0.119128  0.078794
# TOV  0.042223  0.217822  0.071847  0.254640  0.247301  0.117952  0.302224
# MP   0.093499  0.276937  1.000000  0.201792  0.203968  0.075831  0.109071
# FTA  0.235582  0.170495  0.034774  0.088732  0.228251  0.068501  0.177662
# TRB  0.391776  0.353218  0.043104  0.332424  0.455716  0.050171  0.174593
# STL  0.292466  0.062016  0.055942  0.326819  0.582717  0.049095  0.156561
# BLK  0.208205  0.301515  0.475571  0.244178  0.427365  0.039787  0.149529
# 3P   0.344450  0.172331  0.109071  0.030884  0.078794  0.037364  1.000000
# G    0.129002  1.000000  0.276937  0.030144  0.065681  0.016866  0.172331
#
#           3PA       3P%        2P  ...       FT%       ORB       DRB  \
# FG%  0.309286  0.619791  0.588684  ...  0.209860  0.331860  0.406894
# 2P%  0.139681  0.223327  0.247834  ...  0.015204  0.367025  0.473939
# PTS  0.009681  0.648696  0.502407  ...  0.008966  0.121564  0.289135
# FG   0.297225  0.468075  0.813984  ...  0.075099  0.145494  0.254680
# Rk   0.048610  0.600578  0.474469  ...  0.011357  0.121576  0.350577
# 3P%  0.057485  1.000000  0.110556  ...  0.238268  0.125945  0.152495
# AST  0.170675  0.327807  0.539667  ...  0.088802  0.004958  0.220448
# 2P   0.738197  0.110556  1.000000  ...  0.053278  0.065707  0.132847
# DRB  0.051385  0.152495  0.132847  ...  0.122453  0.307645  1.000000
# ORB  0.161896  0.125945  0.065707  ...  0.328586  1.000000  0.307645
# 3PA  1.000000  0.057485  0.738197  ...  0.345981  0.161896  0.051385
# PF   0.339915  0.210236  0.244492  ...  0.072140  0.167155  0.455514
# FT%  0.345981  0.238268  0.053278  ...  1.000000  0.328586  0.122453
# FT   0.048230  0.203519  0.135728  ...  0.408260  0.123602  0.021863
# 2PA  0.800499  0.008241  0.864277  ...  0.034746  0.269088  0.118337
# FGA  0.034507  0.087542  0.480620  ...  0.395334  0.655510  0.125966
# TOV  0.424787  0.146381  0.385449  ...  0.283243  0.074313  0.041335
# MP   0.042684  0.171472  0.220674  ...  0.073696  0.019097  0.026220
# FTA  0.145622  0.083556  0.180861  ...  0.122247  0.049303  0.052403
# TRB  0.180703  0.014424  0.165253  ...  0.174250  0.606788  0.569438
# STL  0.143939  0.070259  0.167381  ...  0.315955  0.554771  0.123718
# BLK  0.034571  0.234142  0.275825  ...  0.186936  0.289231  0.018539
# 3P   0.868544  0.443144  0.605198  ...  0.189429  0.079950  0.130995
# G    0.212931  0.060339  0.077412  ...  0.234713  0.009501  0.431705
#
#           TRB       AST       STL       BLK       TOV        PF       PTS
# FG%  0.050171  0.608967  0.049095  0.039787  0.117952  0.248948  0.776974
# 2P%  0.077122  0.467686  0.114445  0.008283  0.180405  0.047631  0.578348
# PTS  0.341074  0.521578  0.279283  0.211795  0.091051  0.039395  1.000000
# FG   0.332424  0.690943  0.326819  0.244178  0.254640  0.160968  0.878056
# Rk   0.391776  0.492803  0.292466  0.208205  0.042223  0.010658  0.971318
# 3P%  0.014424  0.327807  0.070259  0.234142  0.146381  0.210236  0.648696
# AST  0.182225  1.000000  0.305519  0.078628  0.030131  0.036395  0.521578
# 2P   0.165253  0.539667  0.167381  0.275825  0.385449  0.244492  0.502407
# DRB  0.569438  0.220448  0.123718  0.018539  0.041335  0.455514  0.289135
# ORB  0.606788  0.004958  0.554771  0.289231  0.074313  0.167155  0.121564
# 3PA  0.180703  0.170675  0.143939  0.034571  0.424787  0.339915  0.009681
# PF   0.235847  0.036395  0.291017  0.208254  0.386180  1.000000  0.039395
# FT%  0.174250  0.088802  0.315955  0.186936  0.283243  0.072140  0.008966
# FT   0.083411  0.391578  0.261581  0.129559  0.124187  0.124011  0.227430
# 2PA  0.132051  0.292250  0.237317  0.284339  0.479613  0.217830  0.202266
# FGA  0.455716  0.265895  0.582717  0.427365  0.247301  0.072786  0.348405
# TOV  0.027337  0.030131  0.051620  0.042565  1.000000  0.386180  0.091051
# MP   0.043104  0.136454  0.055942  0.475571  0.071847  0.252192  0.140234
# FTA  0.000360  0.375786  0.106689  0.232575  0.318063  0.190106  0.248540
# TRB  1.000000  0.182225  0.371772  0.236702  0.027337  0.235847  0.341074
# STL  0.371772  0.305519  1.000000  0.335166  0.051620  0.291017  0.279283
# BLK  0.236702  0.078628  0.335166  1.000000  0.042565  0.208254  0.211795
# 3P   0.174593  0.013018  0.156561  0.149529  0.302224  0.194850  0.336149
# G    0.353218  0.055617  0.062016  0.301515  0.217822  0.222024  0.098181
#
# [24 rows x 24 columns]
